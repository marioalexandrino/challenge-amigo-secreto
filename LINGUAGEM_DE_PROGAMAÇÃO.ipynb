# %% [markdown]
# <a href="https://colab.research.google.com/github/marioalexandrino/challenge-amigo-secreto/blob/main/LINGUAGEM_DE_PROGAMA%C3%87%C3%83O.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #U1_A1

# %%
#1.Nosso primeiro programa

print("hello world")
# Out:
# hello world

# %%
#2.Criando variáveis de tipos diferentes
x = 10
nome = 'Mario'
nota = 8.5
fez_inscricao = True

# %%
print(x)
print(nome)
print(nota)
print(fez_inscricao)
# Out:
# 10
# Mario
# 8.5
# True

# %%
print(type(x))
print(type(nome))
print(type(nota))
print(type(fez_inscricao))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'float'>
# <class 'bool'>

# %%
nome = input('Digite seu nome:')
# Out:
# Digite seu nome:Python

# %%
print(f"Olá {nome}, bem vindo à disciplina de programação")
# Out:
# Olá Python, bem vindo à disciplina de programação

# %%
media = (Nota_1+Nota_2+Nota_3+Nota_4)/4

# %%
print(media)
# Out:
# 6.5

# %%
if media >= 6:
  situacao = "Aprovado"
else:
  situacao = "Reprovado"

# %%
print(situacao)
# Out:
# Aprovado

# %% [markdown]
# #U1_A2

# %%
print(10>5)
# Out:
# True

# %%
print(5>10)
# Out:
# False

# %%
print(7==7)
# Out:
# True

# %%
print(7!=7)
# Out:
# False

# %%
#guardando informaçôes
idade = 20
e_maior_de_idade = idade>=18
print(e_maior_de_idade)
# Out:
# True

# %%
print(True and True)
# Out:
# True

# %%
print (True and False)
# Out:
# False

# %%
idade = int(input("Digite sua idade: "))
if idade < 18:
  print("Menor de idade")
elif idade >= 18 and idade <65:
  print("Adulto")
else:
  print("Idoso")
# Out:
# Digite sua idade: 67
# Idoso

# %%
idade = int(input("Digite sua idade: "))
if idade < 12:
  print("Recomendamos o filme infantil 1")
elif idade >= 12 and idade <18:
  print("Recomendamos o filme infantil 2")
else:
  print("Recomendamos o filme infantil 3")
# Out:
# Digite sua idade: 18
# Recomendamos o filme infantil 3

# %%
quantidade_de_ingresso = 10
if quantidade_de_ingresso > 0:
  print("Ingressos disponíveis. Divirta-se no cinema")
else:
  print("Desculpe, todos os ingressos foram vendidos")
# Out:
# Ingressos disponíveis. Divirta-se no cinema

# %% [markdown]
# ##U1_A3

# %%
numeros = [1,2,3,4,5,6,7]

for numeros in numeros:
  print("%f Camiseta: {numeros}")
# Out:
# %f Camiseta: {numeros}
# %f Camiseta: {numeros}
# %f Camiseta: {numeros}
# %f Camiseta: {numeros}
# %f Camiseta: {numeros}
# %f Camiseta: {numeros}
# %f Camiseta: {numeros}

# %%
print(type(numeros))
# Out:
# <class 'int'>

# %%
numero = int(input("Digite um número"))

while numero !=0:
  if numero %  2 == 0:
    print("O número é par.")
  else:
    print("O número é ímpar.")
numero = int(input("Digite um número(ou 0 para sair): "))

# %%
for x in range(1,15,3):
  print(x)
# Out:
# 1
# 4
# 7
# 10
# 13

# %%
from inspect import classify_class_attrs
filmes = ["1", "2", "3", "4", "5"]
print("Bem vindo a classificação do filme")
print("Você tem cinco filmes para classificar")
print("Digite '0' a qualquer momento para parar.")

for filme in filmes:
  classificacao = input(f"Como você classifica '{filmes}' de 1 a 5 (ou 0 para parar): ")

  if classificacao == '0':
    print ("Que pena")
    break

  classificacao = int(classificacao)
  if classificacao <1 or classificacao >5:
    print("nota inválida")
  else:
    print(f"Você classificou '{filmes}' com  '{classificacao}' estrelas.\n")
  print("obrigado")
# Out:
# Bem vindo a classificação do filme
# Você tem cinco filmes para classificar
# Digite '0' a qualquer momento para parar.
# Como você classifica '['1', '2', '3', '4', '5']' de 1 a 5 (ou 0 para parar): 1
# Você classificou '['1', '2', '3', '4', '5']' com  '1' estrelas.
#
# obrigado
# Como você classifica '['1', '2', '3', '4', '5']' de 1 a 5 (ou 0 para parar): 2
# Você classificou '['1', '2', '3', '4', '5']' com  '2' estrelas.
#
# obrigado
# Como você classifica '['1', '2', '3', '4', '5']' de 1 a 5 (ou 0 para parar): 3
# Você classificou '['1', '2', '3', '4', '5']' com  '3' estrelas.
#
# obrigado
# Como você classifica '['1', '2', '3', '4', '5']' de 1 a 5 (ou 0 para parar): 4
# Você classificou '['1', '2', '3', '4', '5']' com  '4' estrelas.
#
# obrigado
# Como você classifica '['1', '2', '3', '4', '5']' de 1 a 5 (ou 0 para parar): 5
# Você classificou '['1', '2', '3', '4', '5']' com  '5' estrelas.
#
# obrigado
