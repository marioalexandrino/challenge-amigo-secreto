# %% [markdown]
# <a href="https://colab.research.google.com/github/marioalexandrino/challenge-amigo-secreto/blob/main/LINGUAGEM_DE_PROGAMA%C3%87%C3%83O.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #U1_A1

# %%
#1.Nosso primeiro programa

print("hello world")

# %%
#2.Criando variáveis de tipos diferentes
x = 10
nome = 'Mario'
nota = 8.5
fez_inscricao = True

# %%
print(x)
print(nome)
print(nota)
print(fez_inscricao)

# %%
print(type(x))
print(type(nome))
print(type(nota))
print(type(fez_inscricao))

# %%
nome = input('Digite seu nome:')

# %%
print(f"Olá {nome}, bem vindo à disciplina de programação")

# %%
media = (Nota_1+Nota_2+Nota_3+Nota_4)/4

# %%
print(media)

# %%
if media >= 6:
  situacao = "Aprovado"
else:
  situacao = "Reprovado"

# %%
print(situacao)

# %% [markdown]
# #U1_A2

# %%
print(10>5)

# %%
print(5>10)

# %%
print(7==7)

# %%
print(7!=7)

# %%
#guardando informaçôes
idade = 20
e_maior_de_idade = idade>=18
print(e_maior_de_idade)

# %%
print(True and True)

# %%
print(True and False)

# %%
idade = int(input("Digite sua idade: "))
if idade < 18:
  print("Menor de idade")
elif idade >= 18 and idade <65:
  print("Adulto")
else:
  print("Idoso")

# %%
idade = int(input("Digite sua idade: "))
if idade < 12:
  print("Recomendamos o filme infantil 1")
elif idade >= 12 and idade <18:
  print("Recomendamos o filme infantil 2")
else:
  print("Recomendamos o filme infantil 3")

# %%
quantidade_de_ingresso = 10
if quantidade_de_ingresso > 0:
  print("Ingressos disponíveis. Divirta-se no cinema")
else:
  print("Desculpe, todos os ingressos foram vendidos")

# %% [markdown]
# ##U1_A3

# %%
numeros = [1,2,3,4,5,6,7]

for numeros in numeros:
  print("%f Camiseta: {numeros}")

# %%
print(type(numeros))

# %%
numero = int(input("Digite um número"))

while numero !=0:
  if numero %  2 == 0:
    print("O número é par.")
  else:
    print("O número é ímpar.")
numero = int(input("Digite um número(ou 0 para sair): "))

# %%
for x in range(1,15,3):
  print(x)

# %%
from inspect import classify_class_attrs
filmes = ["Filme 1", "Filme 2", "Filme 3", "Filme 4", "Filme 5"]
print("Bem vindo a classificação do filme")
print("Você tem cinco filmes para classificar")
print("Digite '0' a qualquer momento para parar.\n")

for filme in filmes:
  classificacao = input(f"Como você classifica '{filme}' de 1 a 5 (ou 0 para parar): ")

  if classificacao == '0':
    print ("Que pena")
    break

  classificacao = int(classificacao)
  if classificacao <1 or classificacao >5:
    print("nota inválida")
  else:
    print(f"Você classificou '{filme}' com  '{classificacao}' estrelas.\n")
print("obrigado")
# Out:
# Bem vindo a classificação do filme
# Você tem cinco filmes para classificar
# Digite '0' a qualquer momento para parar.
#
# Como você classifica 'Filme 1' de 1 a 5 (ou 0 para parar): 1
# Você classificou 'Filme 1' com  '1' estrelas.
#
# Como você classifica 'Filme 2' de 1 a 5 (ou 0 para parar): 2
# Você classificou 'Filme 2' com  '2' estrelas.
#
# Como você classifica 'Filme 3' de 1 a 5 (ou 0 para parar): 3
# Você classificou 'Filme 3' com  '3' estrelas.
#
# Como você classifica 'Filme 4' de 1 a 5 (ou 0 para parar): 4
# Você classificou 'Filme 4' com  '4' estrelas.
#
# Como você classifica 'Filme 5' de 1 a 5 (ou 0 para parar): 5
# Você classificou 'Filme 5' com  '5' estrelas.
#
# obrigado

# %% [markdown]
# ##U1_A4

# %%
numero = [1,2,3,4,5]

comprimento = len(numero)

# %%
comprimento
# Out:
# 5

# %%
range(5)
# Out:
# range(0, 5)

# %%
def soma(a,b):
  resultado = a + b
  return resultado

# %%
resultado_soma = soma(5,6)

# %%
print(resultado_soma)
# Out:
# 11

# %%
def e_par(numero):
  if numero % 2 == 0:
    return True
  else:
    return False

# %%
numero = 2123131233132
teste = e_par(numero)

# %%
print(teste)
# Out:
# True

# %%
media = 8.2124345716798949299718131323792897178694564971627
arredondar_media = lambda media: round(media,2)

# %%
media_arredondada = arredondar_media(media)
print(media_arredondada)
# Out:
# 8.21

# %%
media
# Out:
# 8.212434571679895

# %% [markdown]
# ##ENCERRAMENTO

# %%
#Funçôes definidas pelo usuário
def calcular_desconto(valor, percentual):
  """Calcula o calor final aplicando um desconto percentual"""
  if percentual < 0 or percentual > 100:
    return None #marcação inválida
  desconto = valor * (percentual/100)
  return valor - desconto

def registrar_venda(produto, valor_final):
  """Imprime o registro de uma venda."""
  print(f">> Venda registrada: {produto} por R$ {valor_final:.2f}")

#Função lambda para arredondar

arredondar = lambda v:round(v,2)

# %%
#Variáveis principais do PDV
total_vendas = 0
qtd_vendas = 0

# %%
#Loop principal do caixa. MINHALOJAPDV
while True:
  print("\n----- minha loja - pdv-----")
  print("1 - Registrar Venda")
  print("2 - Ver relatório do dia")
  print("0 - Encerrar Caixa")
  opcao = input("Escolha uma opção: ")

  if opcao == '0':
    print("Encerrando o caixa. Até amanhã")
    break

  elif opcao == "1":
    produto = input("Nome do Produto: ")
    valor = float(input("Valor do Produto: R$ "))
    percentual = float(input("Desconto (%): "))

    valor_final = calcular_desconto(valor,percentual)

    if valor_final is None:
      print("Desconto Inválido: Use um valor entre 0 e 100")
    else:
      valor_final = arredondar(valor_final)
      registrar_venda(produto, valor_final)
      total_vendas = total_vendas + valor_final
      qtd_vendas = qtd_vendas + 1

  elif opcao == "2":
    print(f"\nVendas hoje: {qtd_vendas}")
    print(f"Total faturado: R$ {arredondar(total_vendas)}")

  else:
   print("Opção Inválida. Tente de novo")
# Out:
# ----- minha loja - pdv-----
# 1 - Registrar Venda
# 2 - Ver relatório do dia
# 0 - Encerrar Caixa
# Escolha uma opção: 1
# Nome do Produto: Pão
# Valor do Produto: R$ 10
# Desconto (%): 10
# >> Venda registrada: Pão por R$ 9.00
#
# ----- minha loja - pdv-----
# 1 - Registrar Venda
# 2 - Ver relatório do dia
# 0 - Encerrar Caixa
# Escolha uma opção: 1
# Nome do Produto: Café
# Valor do Produto: R$ 5
# Desconto (%): 5
# >> Venda registrada: Café por R$ 4.75
#
# ----- minha loja - pdv-----
# 1 - Registrar Venda
# 2 - Ver relatório do dia
# 0 - Encerrar Caixa
# Escolha uma opção: 0
# Encerrando o caixa. Até amanhã
